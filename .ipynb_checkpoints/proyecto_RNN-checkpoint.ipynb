# %% [markdown]
# # Proyecto Data Science

# %% [markdown]
# ## Estimación de la producción acumulada de petróleo y gas

# %% [markdown]
# Realizado por Rafael Marcano

# %% [markdown]
# ## Introducción

# %% [markdown]
# Este proyecto trata de realizar la estimación de la producción petrolera.

# %% [markdown]
# En los datos encontramos secuencias de longitud arbitraria por lo tanto se usará redes neuronales recurrentes (RNN).

# %% [markdown]
# Con tensorflow y Keras en general se hará la construcción del modelo.

# %% [markdown]
# ## Librerias

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from productionScript import Production
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM

# %%
root = "/home/rafael/Documentos/Produccion_Petrolera_Data/DATALOGGER/"
fileNames = "productionList.txt"

# %% [markdown]
# ## Clases para la extraction de los datos

# %%
class Read:
    def __init__(self, year):
        self.year = year

    def documents(self):
        filesList = []
        commandLine = "ls " + root + str(self.year) + " > " + fileNames
        try:
            os.system(commandLine)
            file = pd.read_csv(fileNames, sep="\t", header= None, squeeze=True)
            for element in file:
                filesList.append(root + str(self.year) + "/" + element)
        except FileNotFoundError as fnf_error:
            print(fnf_error)
        return filesList

class Data:
    def __init__(self, year):
        self.year = year
        self.documents = Read(year).documents()
        
    def load(self):
        content = []
        headers = []
        count = 0
        try:
            for element in self.documents:
                count += 1
                # print("Reading file n° {} ...".format(count))
                columns = ["Date", "Time"]
                data = []
                file = pd.read_csv(element, sep="\t", header= None, squeeze=True)
                obj = pd.DataFrame(file)
            #     # Reading current document
                for line in file:
                    data += [line.split()]
                content.append(data)
                cols = obj.loc[obj[0].str.contains('Tool')]
                size = list(range(0, len(cols)))
                for k in size:
                    for names in ["Press", "Temp"]:
                        columns.append(names + " " + cols[0].tolist()[k].split()[4:][1])
                headers.append(columns)
        except:
            print("No se puedo obtener datos del directorio ", element)
        return [content, headers]

# %% [markdown]
# ## Clases para la preparación de los datos

# %%
class Frame:
    def __init__(self, year):
        self.year = year
        self.load = Data(self.year).load()
        self.data_headers = self.load[1]
        self.data = self.load[0]
        
    def build(self, well):
        target = "Press {}".format(well)
        frames = []
        # Getting content index
        for current_headers in self.data_headers:
            if target in current_headers:
                frame_targets = [i for i,x in enumerate(self.data_headers) if x==current_headers]
        # Building data frame
        try:
            for k in frame_targets:
                columnsRanges = list(range(0,len(self.data_headers[k])))
                frame = pd.DataFrame(self.data[k]).iloc[:,columnsRanges]
                index = frame[frame[0] == "DATE"].index
                obj = frame.drop(range(0,index[0]+int(4)))
                obj[0] = pd.to_datetime(obj[0], infer_datetime_format=True)
                obj[1] = pd.to_timedelta(obj[1])
                obj.columns = self.data_headers[k]
                frames.append(obj)
                # print("Building data frames ...")
        except AssertionError as error:
            print(error)
        return frames
    
class Parameters:
    def __init__(self, well, year):
        self.year = year
        self.well = well
        self.frames = Frame(self.year).build(self.well)

    def getWell(self):
        data = []
        frame = []
        try:
            data = pd.concat(self.frames)
            columns = ["Date", "Press " + self.well, "Temp " + self.well]
            frame = pd.DataFrame(data[columns])
            print("DataFrame {} creado exitosamente.".format(self.well))
        except AssertionError as error:
            print(error)
        return frame

# %% [markdown]
# ## 1.- Data preparation

# %% [markdown]
# Obteniendo parametros de presión y temperatura para el pozo petrólero AP-01

# %%
# Datos de presión y temperatura
param_AP01_2009 = Parameters('AP-01', 2009)
param_AP01_2009 = param_AP01_2009.getWell()

# Datos de producción
prod_AP01 = Production('AP-01')
well_prod_ap01 = prod_AP01.Frame()
# Out:
# DataFrame AP-01 creado exitosamente.

# %% [markdown]
# Uniendo data parametros y producción en un solo Data Frame

# %%
well_prod_ap01.columns = ["Date", "Oil", "Gas"]
well_prod_ap01["Date"] = pd.to_datetime(well_prod_ap01["Date"], infer_datetime_format=True)
data_set = pd.merge(param_AP01_2009, well_prod_ap01, on="Date")

# %% [markdown]
# Característica de los datos

# %%
data_set.describe()
# Out:
#                        Date Press AP-01 Temp AP-01           Oil           Gas
# count               1070662     1070662    1070662  1.070662e+06  1.070662e+06
# unique                  333       17599          4  3.310000e+02  3.310000e+02
# top     2009-01-25 00:00:00    2322.410    156.000  1.441532e+06  7.503989e+08
# freq                   5764       10065     549581  5.764000e+03  5.764000e+03
# first   2009-01-08 00:00:00         NaN        NaN           NaN           NaN
# last    2010-01-02 00:00:00         NaN        NaN           NaN           NaN

# %% [markdown]
# ## 2.- Data cleaning

# %%
data_set[["Press AP-01", "Temp AP-01", "Oil", "Gas"]] = data_set[["Press AP-01", "Temp AP-01", "Oil", "Gas"]].astype(float)
data_set = data_set.groupby("Date").mean().dropna()

# %% [markdown]
# Trazos de relaciones por pares del conjunto de datos

# %%
g = sns.pairplot(data_set, diag_kind="kde")
# Out:
# /home/rafael/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## 3.- Modeling

# %% [markdown]
# Datos estadísticos

# %%
data_set.describe()
# Out:
#        Press AP-01  Temp AP-01           Oil           Gas
# count   333.000000  333.000000  3.330000e+02  3.330000e+02
# mean   2339.045064  155.511013  1.313470e+06  6.744679e+08
# std      43.992218    0.438133  2.984554e+05  1.449765e+08
# min    2275.965305  154.969134  7.597161e+05  4.051087e+08
# 25%    2307.189695  155.000000  1.064799e+06  5.533765e+08
# 50%    2326.360590  155.500000  1.333060e+06  6.854821e+08
# 75%    2364.612697  155.997917  1.571881e+06  8.017503e+08
# max    2456.862776  156.000000  1.800650e+06  9.085322e+08

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 333 entries, 2009-01-08 to 2010-01-02
# Data columns (total 4 columns):
# Press AP-01    333 non-null float64
# Temp AP-01     333 non-null float64
# Oil            333 non-null float64
# Gas            333 non-null float64
# dtypes: float64(4)
# memory usage: 23.0 KB

# %% [markdown]
# ### Gráficos de presión y temperatura

# %%
# Plotting
plt.figure()
plt.title('Pressure AP-01')
plt.plot(data_set['Press AP-01'], 'cyan')
plt.figure()
plt.title('Temperature AP-01')
plt.plot(data_set['Temp AP-01'], 'red')

# %% [markdown]
# ### Normalización de los datos de producción

# %%
from sklearn.preprocessing import MinMaxScaler

maft_oil = data_set['Oil']
matf_press = data_set['Gas']

matf_press = matf_press.values.reshape(len(matf_press), 1)
maft_oil = maft_oil.values.reshape(len(maft_oil), 1)


sc = MinMaxScaler(feature_range=(0,1))

maft_oil = sc.fit_transform(maft_oil)
matf_press = sc.fit_transform(matf_press)

# %% [markdown]
# ### Gráficos producción de petróleo

# %%
# Plotting
plt.title('Accumulative oil and gas production')
plt.plot(matf_press)
plt.plot(maft_oil)
plt.show()

# %% [markdown]
# Dividiendo los datos para entrenamiento y pruebas

# %%
dataset = data_set.iloc[:,2:3].values
dataset = sc.fit_transform(dataset)

train_size = int(len(dataset) * 0.60) 
test_size = len(dataset) - train_size

train, test = dataset[test_size:len(dataset)], dataset[train_size:len(dataset)]

# %%
print("Train and Test shape {} {}".format(train.shape, test.shape))
# Out:
# Train and Test shape (199, 1) (134, 1)

# %% [markdown]
# Dando nueva forma a los datos. Necesarios para la red neuronal.

# %%
X_train, y_train = [], []
for i in range(30, len(train)):
    X_train.append(train[i-30:i,0])
    y_train.append(train[i,0])
    
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
print("Train shape {}".format(X_train.shape))
# Out:
# Train shape (169, 30, 1)

# %%
y_test = []
for i in range(30, len(test)):
    y_test.append(test[i-30:i,0])

y_test = np.array(y_test)
y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1], 1))

# %%
print("Test shape {}".format(y_test.shape))
# Out:
# Test shape (104, 30, 1)

# %% [markdown]
# ### Construcción de la red neuronal recurrente

# %%
regresor = Sequential()

# Layers
regresor.add(LSTM(50, return_sequences = True, input_shape=(30,1)))
regresor.add(Dropout(.2))
regresor.add(LSTM(50, return_sequences = True))
regresor.add(Dropout(.2))
regresor.add(LSTM(50, return_sequences = False))
regresor.add(Dense(1))

#Optimizer
from tensorflow.keras.optimizers import Adam
opt = Adam(lr=1e-3, decay=1e-5)

# Compile
regresor.compile(optimizer=opt, loss='mean_squared_error', metrics=['accuracy'])

# %% [markdown]
# ## 4.- Validation

# %%
# Entrenamiento
history = regresor.fit(X_train, y_train, epochs = 100, batch_size=32)
# Out:
# Epoch 1/100
# 169/169 [==============================] - 4s 25ms/sample - loss: 0.4817 - acc: 0.0000e+00
# Epoch 2/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0636 - acc: 0.0059
# Epoch 3/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0265 - acc: 0.0059
# Epoch 4/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0285 - acc: 0.0059
# Epoch 5/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0080 - acc: 0.0059
# Epoch 6/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0107 - acc: 0.0059
# Epoch 7/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0039 - acc: 0.0059
# Epoch 8/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0054 - acc: 0.0059
# Epoch 9/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0037 - acc: 0.0059
# Epoch 10/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0033 - acc: 0.0059
# Epoch 11/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0037 - acc: 0.0059
# Epoch 12/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0037 - acc: 0.0059
# Epoch 13/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0027 - acc: 0.0059
# Epoch 14/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0027 - acc: 0.0059
# Epoch 15/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0023 - acc: 0.0059
# Epoch 16/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0024 - acc: 0.0059
# Epoch 17/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0024 - acc: 0.0059
# Epoch 18/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0021 - acc: 0.0059
# Epoch 19/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0019 - acc: 0.0059
# Epoch 20/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0021 - acc: 0.0059
# Epoch 21/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0014 - acc: 0.0059
# Epoch 22/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0016 - acc: 0.0059
# Epoch 23/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0014 - acc: 0.0059
# Epoch 24/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0012 - acc: 0.0059
# Epoch 25/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0012 - acc: 0.0059
# Epoch 26/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 9.6489e-04 - acc: 0.0059
# Epoch 27/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0010 - acc: 0.0059
# Epoch 28/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 0.0012 - acc: 0.0059
# Epoch 29/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 9.0272e-04 - acc: 0.0059
# Epoch 30/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 9.0518e-04 - acc: 0.0059
# Epoch 31/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 8.8798e-04 - acc: 0.0059
# Epoch 32/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 8.0567e-04 - acc: 0.0059
# Epoch 33/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 7.4775e-04 - acc: 0.0059
# Epoch 34/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 7.4304e-04 - acc: 0.0059
# Epoch 35/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 8.7848e-04 - acc: 0.0059
# Epoch 36/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 7.6784e-04 - acc: 0.0059
# Epoch 37/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 8.2627e-04 - acc: 0.0059
# Epoch 38/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 8.2329e-04 - acc: 0.0059
# Epoch 39/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 8.6777e-04 - acc: 0.0059
# Epoch 40/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 9.4246e-04 - acc: 0.0059
# Epoch 41/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 8.3228e-04 - acc: 0.0059
# Epoch 42/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 8.7232e-04 - acc: 0.0059
# Epoch 43/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 8.0408e-04 - acc: 0.0059
# Epoch 44/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.6102e-04 - acc: 0.0059
# Epoch 45/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.7607e-04 - acc: 0.0059
# Epoch 46/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.9693e-04 - acc: 0.0059
# Epoch 47/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.8383e-04 - acc: 0.0059
# Epoch 48/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 7.1123e-04 - acc: 0.0059
# Epoch 49/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.6754e-04 - acc: 0.0059
# Epoch 50/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.6110e-04 - acc: 0.0059
# Epoch 51/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 7.1994e-04 - acc: 0.0059
# Epoch 52/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.3823e-04 - acc: 0.0059
# Epoch 53/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 7.3681e-04 - acc: 0.0059
# Epoch 54/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.1109e-04 - acc: 0.0059
# Epoch 55/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 7.5901e-04 - acc: 0.0059
# Epoch 56/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.0536e-04 - acc: 0.0059
# Epoch 57/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 4.8584e-04 - acc: 0.0059
# Epoch 58/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.8597e-04 - acc: 0.0059
# Epoch 59/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 7.1154e-04 - acc: 0.0059
# Epoch 60/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.2960e-04 - acc: 0.0059
# Epoch 61/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 7.8547e-04 - acc: 0.0059
# Epoch 62/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.3808e-04 - acc: 0.0059
# Epoch 63/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.2556e-04 - acc: 0.0059
# Epoch 64/100
# 169/169 [==============================] - 1s 5ms/sample - loss: 4.8004e-04 - acc: 0.0059
# Epoch 65/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.6972e-04 - acc: 0.0059
# Epoch 66/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 7.2124e-04 - acc: 0.0059
# Epoch 67/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.3223e-04 - acc: 0.0059
# Epoch 68/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.9431e-04 - acc: 0.0059
# Epoch 69/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.0720e-04 - acc: 0.0059
# Epoch 70/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.9146e-04 - acc: 0.0059
# Epoch 71/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.7648e-04 - acc: 0.0059
# Epoch 72/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.8142e-04 - acc: 0.0059
# Epoch 73/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.8647e-04 - acc: 0.0059
# Epoch 74/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 7.2291e-04 - acc: 0.0059
# Epoch 75/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.2728e-04 - acc: 0.0059
# Epoch 76/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 4.9889e-04 - acc: 0.0059
# Epoch 77/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.1295e-04 - acc: 0.0059
# Epoch 78/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.6409e-04 - acc: 0.0059
# Epoch 79/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 8.3521e-04 - acc: 0.0059
# Epoch 80/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.7409e-04 - acc: 0.0059
# Epoch 81/100
# 169/169 [==============================] - 1s 5ms/sample - loss: 7.1973e-04 - acc: 0.0059
# Epoch 82/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 3.7934e-04 - acc: 0.0059
# Epoch 83/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.6635e-04 - acc: 0.0059
# Epoch 84/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.4876e-04 - acc: 0.0059
# Epoch 85/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.5054e-04 - acc: 0.0059
# Epoch 86/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.3758e-04 - acc: 0.0059
# Epoch 87/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.0933e-04 - acc: 0.0059
# Epoch 88/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 4.7118e-04 - acc: 0.0059
# Epoch 89/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 4.6832e-04 - acc: 0.0059
# Epoch 90/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 4.0298e-04 - acc: 0.0059
# Epoch 91/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 4.7563e-04 - acc: 0.0059
# Epoch 92/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 3.7119e-04 - acc: 0.0059
# Epoch 93/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 4.5168e-04 - acc: 0.0059
# Epoch 94/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 4.5636e-04 - acc: 0.0059
# Epoch 95/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 6.2065e-04 - acc: 0.0059
# Epoch 96/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 4.2511e-04 - acc: 0.0059
# Epoch 97/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 4.9519e-04 - acc: 0.0059
# Epoch 98/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 4.7447e-04 - acc: 0.0059
# Epoch 99/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 5.0557e-04 - acc: 0.0059
# Epoch 100/100
# 169/169 [==============================] - 1s 4ms/sample - loss: 4.0291e-04 - acc: 0.0059

# %% [markdown]
# ### Métricas

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#         loss       acc  epoch
# 95  0.000425  0.005917     95
# 96  0.000495  0.005917     96
# 97  0.000474  0.005917     97
# 98  0.000506  0.005917     98
# 99  0.000403  0.005917     99

# %% [markdown]
# ### Error medio cuadrático

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('MSE')
    plt.plot(hist['epoch'], hist['loss'],
               label='Train Error')
    plt.legend()
    plt.show()

plot_history(history)

# %% [markdown]
# ### Predicción producción petróleo acumulado

# %%
predicted_oil = regresor.predict(y_test)

# %%
oil_predicted = []

for y_predicted in predicted_oil:
    oil_predicted.append(y_predicted[0])

values_predicted = np.array(oil_predicted)
test_values = test.reshape(-1,1)

# %%
# Gráficas
plt.figure()
plt.title('Recurrent neural network model')
plt.plot(sc.inverse_transform(test_values), color='red', label='Real Value')
plt.plot(sc.inverse_transform(values_predicted.reshape(-1,1)), 'k--', color='blue', label='Predicted Value')
plt.legend()
plt.show()
